# %% [markdown]
# ## Практическое задание

# %% [markdown]
# <ol>
#     <li>Попробуйте обучить нейронную сеть на Keras с другими параметрами.
#         Опишите в комментарии к уроку - какой результата вы добились от нейросети? Что помогло вам улучшить ее точность?</li>
#     <li>Поработайте с документацией Keras.</li>
# </ol>

# %%
def accuracy(y_true, y_pred):
    return np.mean(y_true == y_pred)

# %%
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)

# %%
# The full neural network code!
###############################
import numpy as np
import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

train_images = mnist.train_images()
train_labels = mnist.train_labels()
test_images = mnist.test_images()
test_labels = mnist.test_labels()

# Normalize the images.
train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

# Flatten the images.
train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

# Build the model.
model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax'),
])

# Compile the model.
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# Train the model.
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=5,
  batch_size=32,
)

# Evaluate the model.
model.evaluate(
  test_images,
  to_categorical(test_labels)
)

# Save the model to disk.
model.save_weights('model.h5')

# Load the model from disk later using:
# model.load_weights('model.h5')

# Predict on the first 5 test images.
predictions = model.predict(test_images)

# Print our model's predictions.
print(np.argmax(predictions, axis=1)) # [7, 2, 1, 0, 4]

# Check our predictions against the ground truths.
print(test_labels) # [7, 2, 1, 0, 4]

print(f'Accuracy: {accuracy(test_labels, np.argmax(predictions, axis=1))}')
# Out:
# Using TensorFlow backend.
# Epoch 1/5
# 60000/60000 [==============================] - 2s 33us/step - loss: 0.3644 - accuracy: 0.8908
# Epoch 2/5
# 60000/60000 [==============================] - 2s 31us/step - loss: 0.1856 - accuracy: 0.9430
# Epoch 3/5
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1439 - accuracy: 0.9561
# Epoch 4/5
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1239 - accuracy: 0.9613
# Epoch 5/5
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1065 - accuracy: 0.9669
# 10000/10000 [==============================] - 0s 14us/step
# [7 2 1 ... 4 5 6]
# [7 2 1 ... 4 5 6]
# Accuracy: 0.9652

# %%
# Попробуем увеличить число эпох

# Build the model.
model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax'),
])

# Compile the model.
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# Train the model.
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=10,
  batch_size=32,
)

# Evaluate the model.
model.evaluate(
  test_images,
  to_categorical(test_labels)
)

# Save the model to disk.
# model.save_weights('model.h5')

# Load the model from disk later using:
# model.load_weights('model.h5')

# Predict on the first 5 test images.
predictions = model.predict(test_images)

# Print our model's predictions.
print(np.argmax(predictions, axis=1)) # [7, 2, 1, 0, 4]

# Check our predictions against the ground truths.
print(test_labels) # [7, 2, 1, 0, 4]

print(f'Accuracy: {accuracy(test_labels, np.argmax(predictions, axis=1))}')
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.3668 - accuracy: 0.8895
# Epoch 2/10
# 60000/60000 [==============================] - 2s 30us/step - loss: 0.1813 - accuracy: 0.9448
# Epoch 3/10
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1412 - accuracy: 0.9567
# Epoch 4/10
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.1201 - accuracy: 0.9638
# Epoch 5/10
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.1050 - accuracy: 0.9671
# Epoch 6/10
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0952 - accuracy: 0.9698
# Epoch 7/10
# 60000/60000 [==============================] - 2s 29us/step - loss: 0.0862 - accuracy: 0.9727
# Epoch 8/10
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0793 - accuracy: 0.9747
# Epoch 9/10
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0727 - accuracy: 0.9765
# Epoch 10/10
# 60000/60000 [==============================] - 2s 28us/step - loss: 0.0680 - accuracy: 0.9780
# 10000/10000 [==============================] - 0s 13us/step
# [7 2 1 ... 4 5 6]
# [7 2 1 ... 4 5 6]
# Accuracy: 0.9655

# %%
# Изменим кол-во слоев и нейронов в каждом слое

# Build the model.
model = Sequential([
  Dense(512, activation='relu', input_shape=(784,)),
  Dense(256, activation='relu'),
  Dense(128, activation='relu'),
  Dense(10, activation='softmax'),
])

# Compile the model.
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# Train the model.
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=10,
  batch_size=32,
)

# Evaluate the model.
model.evaluate(
  test_images,
  to_categorical(test_labels)
)

# Save the model to disk.
# model.save_weights('model.h5')

# Load the model from disk later using:
# model.load_weights('model.h5')

# Predict on the first 5 test images.
predictions = model.predict(test_images)

# Print our model's predictions.
print(np.argmax(predictions, axis=1)) # [7, 2, 1, 0, 4]

# Check our predictions against the ground truths.
print(test_labels) # [7, 2, 1, 0, 4]

print(f'Accuracy: {accuracy(test_labels, np.argmax(predictions, axis=1))}')
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 9s 144us/step - loss: 0.2802 - accuracy: 0.9126
# Epoch 2/10
# 60000/60000 [==============================] - 9s 144us/step - loss: 0.1422 - accuracy: 0.9570
# Epoch 3/10
# 60000/60000 [==============================] - 9s 146us/step - loss: 0.1098 - accuracy: 0.9660
# Epoch 4/10
# 60000/60000 [==============================] - 9s 142us/step - loss: 0.0886 - accuracy: 0.9726
# Epoch 5/10
# 60000/60000 [==============================] - 8s 137us/step - loss: 0.0756 - accuracy: 0.9762
# Epoch 6/10
# 60000/60000 [==============================] - 8s 139us/step - loss: 0.0673 - accuracy: 0.9791
# Epoch 7/10
# 60000/60000 [==============================] - 8s 140us/step - loss: 0.0611 - accuracy: 0.9803
# Epoch 8/10
# 60000/60000 [==============================] - 8s 137us/step - loss: 0.0527 - accuracy: 0.9834
# Epoch 9/10
# 60000/60000 [==============================] - 8s 137us/step - loss: 0.0497 - accuracy: 0.9838
# Epoch 10/10
# 60000/60000 [==============================] - 8s 139us/step - loss: 0.0462 - accuracy: 0.9851
# 10000/10000 [==============================] - 0s 27us/step
# [7 2 1 ... 4 5 6]
# [7 2 1 ... 4 5 6]
# Accuracy: 0.9742

# %%
# Получилось достичь следующего результата на всем тестовом наборе:
# Accuracy: 0.9742 vs Accuracy: 0.9652 (пример из урока).
# Улучшить точность помогло увеличение числа эпох с 5 до 10,
# а также изменение кол-ва словев и числа нейронов в них.

# %%
# Полезные функции Keras

# keras.utils.normalize
# https://keras.io/api/utils/python_utils/#normalize-function

# keras.utils.serialize_keras_object
# https://keras.io/api/utils/serialization_utils/

# deserialize_keras_object
# https://keras.io/api/utils/serialization_utils/
